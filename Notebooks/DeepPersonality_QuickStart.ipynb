# %% [markdown]
# # Installation

# %%
# !git clone https://github.com/liaorongfan/DeepPersonality.git
# Out:
# Cloning into 'DeepPersonality'...
# remote: Enumerating objects: 3247, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 3247 (delta 29), reused 37 (delta 19), pack-reused 3183
# Receiving objects: 100% (3247/3247), 3.05 MiB | 20.84 MiB/s, done.
# Resolving deltas: 100% (2279/2279), done.

# %%
import os
os.chdir("/content/DeepPersonality")
os.getcwd()
# Out:
# /content/DeepPersonality

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Quick Start

# %% [markdown]
# ## Download processed demo dataset
# If you just want to have a try on running demo experiment, you can download the pre-processed tiny Chalearn 2016 dataset and unzip it in the `datasets` directory

# %%
# !gdown --id 1eANtFzA75Mqv01nW45exfauAIMLNO70J --output ChaLearn2016_tiny_processed.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1eANtFzA75Mqv01nW45exfauAIMLNO70J
# To: /content/DeepPersonality/ChaLearn2016_tiny_processed.zip
# 100% 1.59G/1.59G [00:27<00:00, 58.2MB/s]

# %%
# !unzip ChaLearn2016_tiny_processed.zip -d datasets

# %% [markdown]
# ## Run demo expriment

# %%
# !python script/run_exp.py -c /content/DeepPersonality/config/demo/bimodal_resnet18.yaml
# Out:
# {
#     "DATA":{
#         "ROOT":"datasets",
#         "SESSION":"talk",
#         "TEST_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/test_data",
#         "TEST_IMG_DATA":"ChaLearn2016_tiny/test_data",
#         "TEST_IMG_FACE_DATA":"image_data/test_data_face",
#         "TEST_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_test.pkl",
#         "TRAIN_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/train_data",
#         "TRAIN_IMG_DATA":"ChaLearn2016_tiny/train_data",
#         "TRAIN_IMG_FACE_DATA":"image_data/train_data_face",
#         "TRAIN_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_training.pkl",
#         "TYPE":"frame",
#         "VALID_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/valid_data",
#         "VALID_IMG_DATA":"ChaLearn2016_tiny/valid_data",
#         "VALID_IMG_FACE_DATA":"image_data/valid_data_face",
#         "VALID_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_validation.pkl",
#         "VA_DATA":"va_data/cropped_aligned",
#         "VA_ROOT":"datasets",
#         "VA_TRAIN_LABEL":"va_data/va_label/VA_Set/Train_Set",
#         "VA_VALID_LABEL":"va_data/va_label/VA_Set/Validation_Set"
#     },
#     "DATA_LOADER":{
#         "DATASET":"",
#         "DROP_LAST":true,
#         "NAME":"bimodal_resnet_data_loader",
#         "NUM_WORKERS":0,
#         "SECOND_STAGE":{
#             "METHOD":"",
#             "TYPE":""
#         },
#         "SHUFFLE":true,
#         "TRAIN_BATCH_SIZE":8,
#         "TRANSFORM":"standard_frame_transform",
#         "VALID_BATCH_SIZE":4
#     },
#     "LOSS":{
#         "NAME":"mean_square_error"
#     },
#     "MODEL":{
#         "NAME":"audiovisual_resnet",
#         "NUM_CLASS":5,
#         "PRETRAIN":false,
#         "RETURN_FEATURE":false,
#         "SPECTRUM_CHANNEL":50
#     },
#     "SOLVER":{
#         "BETA_1":0.5,
#         "BETA_2":0.999,
#         "FACTOR":0.1,
#         "LR_INIT":0.001,
#         "MILESTONE":[
#             100,
#             200
#         ],
#         "MOMENTUM":0.9,
#         "NAME":"sgd",
#         "RESET_LR":false,
#         "SCHEDULER":"multi_step_scale",
#         "WEIGHT_DECAY":0.0005
#     },
#     "TEST":{
#         "COMPUTE_CCC":true,
#         "COMPUTE_PCC":true,
#         "FULL_TEST":false,
#         "SAVE_DATASET_OUTPUT":"",
#         "TEST_ONLY":false,
#         "WEIGHT":""
#     },
#     "TRAIN":{
#         "LOG_INTERVAL":10,
#         "MAX_EPOCH":50,
#         "OUTPUT_DIR":"results/demo/unified_frame_images/03_bimodal_resnet",
#         "PRE_TRAINED_MODEL":null,
#         "RESUME":"",
#         "START_EPOCH":0,
#         "TRAINER":"BiModalTrainer",
#         "VALID_INTERVAL":1
#     }
# }
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[001/050] Train Mean_Acc: 86.57% Valid Mean_Acc:88.97% OCEAN_ACC:[0.87846386 0.888848   0.8889967  0.9031019  0.8891225 ]
#
# INFO:log.log:Valid: Epoch[001/050] Train Mean_Acc: 86.57% Valid Mean_Acc:88.97% OCEAN_ACC:[0.87846386 0.888848   0.8889967  0.9031019  0.8891225 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[002/050] Train Mean_Acc: 87.01% Valid Mean_Acc:89.12% OCEAN_ACC:[0.8849263 0.8897511 0.8878974 0.9050239 0.8882632]
#
# INFO:log.log:Valid: Epoch[002/050] Train Mean_Acc: 87.01% Valid Mean_Acc:89.12% OCEAN_ACC:[0.8849263 0.8897511 0.8878974 0.9050239 0.8882632]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[003/050] Train Mean_Acc: 87.03% Valid Mean_Acc:89.24% OCEAN_ACC:[0.89070016 0.8898274  0.8878897  0.90540123 0.88820696]
#
# INFO:log.log:Valid: Epoch[003/050] Train Mean_Acc: 87.03% Valid Mean_Acc:89.24% OCEAN_ACC:[0.89070016 0.8898274  0.8878897  0.90540123 0.88820696]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[004/050] Train Mean_Acc: 87.72% Valid Mean_Acc:89.36% OCEAN_ACC:[0.8949623  0.89095926 0.8887308  0.90576696 0.8877837 ]
#
# INFO:log.log:Valid: Epoch[004/050] Train Mean_Acc: 87.72% Valid Mean_Acc:89.36% OCEAN_ACC:[0.8949623  0.89095926 0.8887308  0.90576696 0.8877837 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[005/050] Train Mean_Acc: 87.30% Valid Mean_Acc:89.28% OCEAN_ACC:[0.89411736 0.88905275 0.8894617  0.90567267 0.8858142 ]
#
# INFO:log.log:Valid: Epoch[005/050] Train Mean_Acc: 87.30% Valid Mean_Acc:89.28% OCEAN_ACC:[0.89411736 0.88905275 0.8894617  0.90567267 0.8858142 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch

#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[023/050] Train Mean_Acc: 88.25% Valid Mean_Acc:88.08% OCEAN_ACC:[0.88295496 0.8824875  0.88469285 0.8821068  0.8718465 ]
#
# INFO:log.log:Valid: Epoch[023/050] Train Mean_Acc: 88.25% Valid Mean_Acc:88.08% OCEAN_ACC:[0.88295496 0.8824875  0.88469285 0.8821068  0.8718465 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[024/050] Train Mean_Acc: 87.50% Valid Mean_Acc:88.16% OCEAN_ACC:[0.8868474 0.8802929 0.8825785 0.8852903 0.8731515]
#
# INFO:log.log:Valid: Epoch[024/050] Train Mean_Acc: 87.50% Valid Mean_Acc:88.16% OCEAN_ACC:[0.8868474 0.8802929 0.8825785 0.8852903 0.8731515]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[025/050] Train Mean_Acc: 87.92% Valid Mean_Acc:88.17% OCEAN_ACC:[0.886567  0.8817378 0.8833621 0.8833477 0.8734042]
#
# INFO:log.log:Valid: Epoch[025/050] Train Mean_Acc: 87.92% Valid Mean_Acc:88.17% OCEAN_ACC:[0.886567  0.8817378 0.8833621 0.8833477 0.8734042]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[026/050] Train Mean_Acc: 87.69% Valid Mean_Acc:88.15% OCEAN_ACC:[0.8861066  0.8797107  0.8852981  0.8841006  0.87243557]
#
# INFO:log.log:Valid: Epoch[026/050] Train Mean_Acc: 87.69% Valid Mean_Acc:88.15% OCEAN_ACC:[0.8861066  0.8797107  0.8852981  0.8841006  0.87243557]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[027/050] Train Mean_Acc: 87.64% Valid Mean_Acc:88.13% OCEAN_ACC:[0.88548774 0.88060033 0.8833774  0.8838748  0.8732131 ]
#
# INFO:log.log:Valid: Epoch[027/050] Train Mean_Acc: 87.64% Valid Mean_Acc:88.13% OCEAN_ACC:[0.88548774 0.88060033 0.8833774  0.8838748  0.8732131 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[028/050] Train Mean_Acc: 87.93% Valid Mean_Acc:88.29% OCEAN_ACC:[0.8880234  0.8822362  0.88905555 0.88419974 0.8711389 ]
#
# INFO:log.log:Valid: Epoch[028/050] Train Mean_Acc: 87.93% Valid Mean_Acc:88.29% OCEAN_ACC:[0.8880234  0.8822362  0.88905555 0.88419974 0.8711389 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[029/050] Train Mean_Acc: 87.39% Valid Mean_Acc:87.55% OCEAN_ACC:[0.87650806 0.8758489  0.87669116 0.8784174  0.87014663]
#
# INFO:log.log:Valid: Epoch[029/050] Train Mean_Acc: 87.39% Valid Mean_Acc:87.55% OCEAN_ACC:[0.87650806 0.8758489  0.87669116 0.8784174  0.87014663]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[030/050] Train Mean_Acc: 87.77% Valid Mean_Acc:88.23% OCEAN_ACC:[0.8871509 0.8820235 0.887259  0.8836563 0.8712571]
#
# INFO:log.log:Valid: Epoch[030/050] Train Mean_Acc: 87.77% Valid Mean_Acc:88.23% OCEAN_ACC:[0.8871509 0.8820235 0.887259  0.8836563 0.8712571]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[031/050] Train Mean_Acc: 87.95% Valid Mean_Acc:88.05% OCEAN_ACC:[0.8831035  0.8804447  0.8823638  0.88418025 0.87245226]
#
# INFO:log.log:Valid: Epoch[031/050] Train Mean_Acc: 87.95% Valid Mean_Acc:88.05% OCEAN_ACC:[0.8831035  0.8804447  0.8823638  0.88418025 0.87245226]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[032/050] Train Mean_Acc: 87.62% Valid Mean_Acc:88.05% OCEAN_ACC:[0.88487834 0.8810506  0.88343036 0.88384074 0.86952364]
#
# INFO:log.log:Valid: Epoch[032/050] Train Mean_Acc: 87.62% Valid Mean_Acc:88.05% OCEAN_ACC:[0.88487834 0.8810506  0.88343036 0.88384074 0.86952364]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[033/050] Train Mean_Acc: 87.90% Valid Mean_Acc:88.06% OCEAN_ACC:[0.8859911  0.88020325 0.8843398  0.8836198  0.86901104]
#
# INFO:log.log:Valid: Epoch[033/050] Train Mean_Acc: 87.90% Valid Mean_Acc:88.06% OCEAN_ACC:[0.8859911  0.88020325 0.8843398  0.8836198  0.86901104]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[034/050] Train Mean_Acc: 87.89% Valid Mean_Acc:88.02% OCEAN_ACC:[0.8867806  0.87867385 0.8835877  0.8812951  0.8705629 ]
#
# INFO:log.log:Valid: Epoch[034/050] Train Mean_Acc: 87.89% Valid Mean_Acc:88.02% OCEAN_ACC:[0.8867806  0.87867385 0.8835877  0.8812951  0.8705629 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[035/050] Train Mean_Acc: 88.19% Valid Mean_Acc:88.10% OCEAN_ACC:[0.8869956  0.8792492  0.8848063  0.8829771  0.87109786]
#
# INFO:log.log:Valid: Epoch[035/050] Train Mean_Acc: 88.19% Valid Mean_Acc:88.10% OCEAN_ACC:[0.8869956  0.8792492  0.8848063  0.8829771  0.87109786]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[036/050] Train Mean_Acc: 87.49% Valid Mean_Acc:88.16% OCEAN_ACC:[0.88740873 0.88193655 0.885248   0.88223857 0.8714062 ]
#
# INFO:log.log:Valid: Epoch[036/050] Train Mean_Acc: 87.49% Valid Mean_Acc:88.16% OCEAN_ACC:[0.88740873 0.88193655 0.885248   0.88223857 0.8714062 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[037/050] Train Mean_Acc: 87.96% Valid Mean_Acc:88.16% OCEAN_ACC:[0.8884196 0.8808082 0.8829098 0.8842956 0.8717664]
#
# INFO:log.log:Valid: Epoch[037/050] Train Mean_Acc: 87.96% Valid Mean_Acc:88.16% OCEAN_ACC:[0.8884196 0.8808082 0.8829098 0.8842956 0.8717664]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[038/050] Train Mean_Acc: 88.11% Valid Mean_Acc:88.14% OCEAN_ACC:[0.8876251 0.8824692 0.8831754 0.8823622 0.8713586]
#
# INFO:log.log:Valid: Epoch[038/050] Train Mean_Acc: 88.11% Valid Mean_Acc:88.14% OCEAN_ACC:[0.8876251 0.8824692 0.8831754 0.8823622 0.8713586]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[039/050] Train Mean_Acc: 87.69% Valid Mean_Acc:87.39% OCEAN_ACC:[0.87480414 0.87456524 0.87502986 0.87695587 0.8681882 ]
#
# INFO:log.log:Valid: Epoch[039/050] Train Mean_Acc: 87.69% Valid Mean_Acc:87.39% OCEAN_ACC:[0.87480414 0.87456524 0.87502986 0.87695587 0.8681882 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[040/050] Train Mean_Acc: 87.80% Valid Mean_Acc:87.31% OCEAN_ACC:[0.874276   0.87653047 0.87156713 0.8751408  0.8677796 ]
#
# INFO:log.log:Valid: Epoch[040/050] Train Mean_Acc: 87.80% Valid Mean_Acc:87.31% OCEAN_ACC:[0.874276   0.87653047 0.87156713 0.8751408  0.8677796 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[041/050] Train Mean_Acc: 87.73% Valid Mean_Acc:88.29% OCEAN_ACC:[0.89101106 0.87987155 0.8865693  0.8858566  0.87125444]
#
# INFO:log.log:Valid: Epoch[041/050] Train Mean_Acc: 87.73% Valid Mean_Acc:88.29% OCEAN_ACC:[0.89101106 0.87987155 0.8865693  0.8858566  0.87125444]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[042/050] Train Mean_Acc: 87.94% Valid Mean_Acc:88.17% OCEAN_ACC:[0.8887478  0.88225377 0.8859633  0.88230675 0.8694204 ]
#
# INFO:log.log:Valid: Epoch[042/050] Train Mean_Acc: 87.94% Valid Mean_Acc:88.17% OCEAN_ACC:[0.8887478  0.88225377 0.8859633  0.88230675 0.8694204 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[043/050] Train Mean_Acc: 87.77% Valid Mean_Acc:87.94% OCEAN_ACC:[0.8853508  0.87827265 0.8850374  0.8780576  0.870057  ]
#
# INFO:log.log:Valid: Epoch[043/050] Train Mean_Acc: 87.77% Valid Mean_Acc:87.94% OCEAN_ACC:[0.8853508  0.87827265 0.8850374  0.8780576  0.870057  ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[044/050] Train Mean_Acc: 88.12% Valid Mean_Acc:87.89% OCEAN_ACC:[0.8864973  0.87709886 0.8830641  0.8813783  0.8664209 ]
#
# INFO:log.log:Valid: Epoch[044/050] Train Mean_Acc: 88.12% Valid Mean_Acc:87.89% OCEAN_ACC:[0.8864973  0.87709886 0.8830641  0.8813783  0.8664209 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[045/050] Train Mean_Acc: 87.87% Valid Mean_Acc:87.95% OCEAN_ACC:[0.88654757 0.8786334  0.8833009  0.8798665  0.8689555 ]
#
# INFO:log.log:Valid: Epoch[045/050] Train Mean_Acc: 87.87% Valid Mean_Acc:87.95% OCEAN_ACC:[0.88654757 0.8786334  0.8833009  0.8798665  0.8689555 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[046/050] Train Mean_Acc: 88.46% Valid Mean_Acc:87.74% OCEAN_ACC:[0.88272965 0.87700367 0.8820795  0.87778676 0.8676259 ]
#
# INFO:log.log:Valid: Epoch[046/050] Train Mean_Acc: 88.46% Valid Mean_Acc:87.74% OCEAN_ACC:[0.88272965 0.87700367 0.8820795  0.87778676 0.8676259 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[047/050] Train Mean_Acc: 87.69% Valid Mean_Acc:88.24% OCEAN_ACC:[0.89152765 0.87873983 0.8863862  0.8828114  0.8727646 ]
#
# INFO:log.log:Valid: Epoch[047/050] Train Mean_Acc: 87.69% Valid Mean_Acc:88.24% OCEAN_ACC:[0.89152765 0.87873983 0.8863862  0.8828114  0.8727646 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[048/050] Train Mean_Acc: 87.96% Valid Mean_Acc:88.11% OCEAN_ACC:[0.8862468  0.88125867 0.8858549  0.88235414 0.8696793 ]
#
# INFO:log.log:Valid: Epoch[048/050] Train Mean_Acc: 87.96% Valid Mean_Acc:88.11% OCEAN_ACC:[0.8862468  0.88125867 0.8858549  0.88235414 0.8696793 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[049/050] Train Mean_Acc: 88.11% Valid Mean_Acc:88.17% OCEAN_ACC:[0.88844717 0.88165265 0.8860756  0.8815702  0.8705349 ]
#
# INFO:log.log:Valid: Epoch[049/050] Train Mean_Acc: 88.11% Valid Mean_Acc:88.17% OCEAN_ACC:[0.88844717 0.88165265 0.8860756  0.8815702  0.8705349 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[050/050] Train Mean_Acc: 88.07% Valid Mean_Acc:88.07% OCEAN_ACC:[0.88863117 0.8789259  0.88415337 0.88249046 0.86943024]
#
# INFO:log.log:Valid: Epoch[050/050] Train Mean_Acc: 88.07% Valid Mean_Acc:88.07% OCEAN_ACC:[0.88863117 0.8789259  0.88415337 0.88249046 0.86943024]
#
# 11-07_16-51 done, best acc: 0.8936406373977661 in :3
# INFO:log.log:11-07_16-51 done, best acc: 0.8936406373977661 in :3
# Test only mode
# INFO:log.log:Test only mode
# test with model results/demo/unified_frame_images/03_bimodal_resnet/11-07_16-50/checkpoint_3.pkl
# INFO:log.log:test with model results/demo/unified_frame_images/03_bimodal_resnet/11-07_16-50/checkpoint_3.pkl
# 100% 5/5 [00:00<00:00, 35.38it/s]
# mse: {'O': 0.0142, 'C': 0.017, 'E': 0.0159, 'A': 0.0169, 'N': 0.024} mean: 0.01759999990463257
# INFO:log.log:mse: {'O': 0.0142, 'C': 0.017, 'E': 0.0159, 'A': 0.0169, 'N': 0.024} mean: 0.01759999990463257
# 0.0142 & 0.017 & 0.0159 & 0.0169 & 0.024 & 0.0176
# acc: {'O': 0.9003, 'C': 0.887, 'E': 0.8982, 'A': 0.8914, 'N': 0.8789} mean: 0.8912
# INFO:log.log:acc: {'O': 0.9003, 'C': 0.887, 'E': 0.8982, 'A': 0.8914, 'N': 0.8789} mean: 0.8912
# 0.9003 & 0.887 & 0.8982 & 0.8914 & 0.8789 & 0.8912
# pcc: {'O': -0.1716, 'C': -0.2332, 'E': -0.1526, 'A': 0.2, 'N': -0.1602} mean: -0.1035
# INFO:log.log:pcc: {'O': -0.1716, 'C': -0.2332, 'E': -0.1526, 'A': 0.2, 'N': -0.1602} mean: -0.1035
# -0.1716 & -0.2332 & -0.1526 & 0.2 & -0.1602 & -0.1035
# ccc: {'O': -0.0145, 'C': -0.0189, 'E': -0.0093, 'A': 0.0135, 'N': -0.0177} mean: -0.0094
# INFO:log.log:ccc: {'O': -0.0145, 'C': -0.0189, 'E': -0.0093, 'A': 0.0135, 'N': -0.0177} mean: -0.0094
# -0.0145 & -0.0189 & -0.0093 & 0.0135 & -0.0177 & -0.0094
